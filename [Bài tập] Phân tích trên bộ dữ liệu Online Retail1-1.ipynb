# %%
import pandas as pd
data_path = 'D:\\codegym\\data\\'
data_name = 'OnlineRetail.csv'
df = pd.read_csv(data_path + data_name,encoding='windows-1252')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
data= df.loc[df['Quantity']>0]
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
table1 = data.pivot_table(values='Quantity', index='InvoiceNo', columns='Country', aggfunc = 'mean')
table1
# Out:
# Country    Australia  Austria  Bahrain  Belgium  Brazil  Canada  \
# InvoiceNo
# 536365           NaN      NaN      NaN      NaN     NaN     NaN
# 536366           NaN      NaN      NaN      NaN     NaN     NaN
# 536367           NaN      NaN      NaN      NaN     NaN     NaN
# 536368           NaN      NaN      NaN      NaN     NaN     NaN
# 536369           NaN      NaN      NaN      NaN     NaN     NaN
# ...              ...      ...      ...      ...     ...     ...
# 581586           NaN      NaN      NaN      NaN     NaN     NaN
# 581587           NaN      NaN      NaN      NaN     NaN     NaN
# A563185          NaN      NaN      NaN      NaN     NaN     NaN
# A563186          NaN      NaN      NaN      NaN     NaN     NaN
# A563187          NaN      NaN      NaN      NaN     NaN     NaN
#
# Country    Channel Islands  Cyprus  Czech Republic  Denmark  ...  RSA  \
# InvoiceNo                                                    ...
# ...

# %%
data.groupby(['CustomerID'])['Quantity'].max()
# Out:
# CustomerID
# 12346.0    74215
# 12347.0      240
# 12348.0      144
# 12349.0       36
# 12350.0       24
#            ...
# 18280.0        8
# 18281.0       12
# 18282.0       48
# 18283.0       13
# 18287.0       60
# Name: Quantity, Length: 4339, dtype: int64

# %%
data.groupby(['CustomerID'])['Quantity'].min()
# Out:
# CustomerID
# 12346.0    74215
# 12347.0        2
# 12348.0        1
# 12349.0        1
# 12350.0        1
#            ...
# 18280.0        2
# 18281.0        1
# 18282.0        1
# 18283.0        1
# 18287.0        4
# Name: Quantity, Length: 4339, dtype: int64

# %%
data.groupby(['StockCode'])['Quantity'].sum()
# Out:
# StockCode
# 10002           1040
# 10080            495
# 10120            193
# 10123C             5
# 10124A            16
#                 ...
# gift_0001_20      20
# gift_0001_30      37
# gift_0001_40       3
# gift_0001_50       4
# m                  1
# Name: Quantity, Length: 3941, dtype: int64

# %%
data.groupby(['StockCode'])['UnitPrice'].mean()
# Out:
# StockCode
# 10002            1.071528
# 10080            0.376667
# 10120            0.210000
# 10123C           0.650000
# 10124A           0.420000
#                   ...
# gift_0001_20    15.038000
# gift_0001_30    21.941250
# gift_0001_40    33.566667
# gift_0001_50    41.890000
# m                2.550000
# Name: UnitPrice, Length: 3941, dtype: float64

# %%
daily  = data.groupby(['InvoiceDate'])['Quantity'].sum().reset_index()
daily
# Out:
#            InvoiceDate  Quantity
# 0      1/10/2011 10:32       260
# 1      1/10/2011 10:35       408
# 2      1/10/2011 10:44        40
# 3      1/10/2011 10:58        83
# 4      1/10/2011 11:09       249
# ...                ...       ...
# 19047    9/9/2011 8:48       104
# 19048    9/9/2011 9:03       105
# 19049    9/9/2011 9:13       372
# 19050    9/9/2011 9:38       204
# 19051    9/9/2011 9:52       782
#
# [19052 rows x 2 columns]
