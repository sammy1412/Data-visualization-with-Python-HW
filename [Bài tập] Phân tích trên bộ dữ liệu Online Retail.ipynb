# %%
import pandas as pd
data_path = 'D:\\codegym\\data\\'
data_name = 'OnlineRetail.csv'
df = pd.read_csv(data_path + data_name,encoding='windows-1252')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.shape
# Out:
# (541909, 8)

# %%
data = df.loc[:,['Description','Quantity']]
data.to_csv('OnlineRetail1.csv')
data
# Out:
#                                 Description  Quantity
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6
# 1                       WHITE METAL LANTERN         6
# 2            CREAM CUPID HEARTS COAT HANGER         8
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4            RED WOOLLY HOTTIE WHITE HEART.         6
# ...                                     ...       ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12
# 541905         CHILDREN'S APRON DOLLY GIRL          6
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908        BAKING SET 9 PIECE RETROSPOT          3
#
# [541909 rows x 2 columns]

# %%
first_1000col = df.iloc[1:1001]
first_1000col.to_csv('OnlineRetail1.csv')
first_1000col
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5       536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# ...        ...       ...                                  ...       ...
# 996     536520     22100             SKULLS SQUARE TISSUE BOX         1
# 997     536520     22096      PINK PAISLEY SQUARE TISSUE BOX          1
# 998     536520     22583         PACK OF 6 HANDBAG GIFT BOXES         1
# 999     536520     21358           TOAST ITS - HAPPY BIRTHDAY         2
# 1000    536520     21123  SET/10 IVORY POLKADOT PARTY CANDLES         1
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
qty = data.loc[df['Quantity']> 10]

qty.to_csv('OnlineRetail1.csv')
qty
# Out:
#                             Description  Quantity
# 9         ASSORTED COLOUR BIRD ORNAMENT        32
# 26            ALARM CLOCK BAKELIKE PINK        24
# 27            ALARM CLOCK BAKELIKE RED         24
# 28           ALARM CLOCK BAKELIKE GREEN        12
# 29      PANDA AND BUNNIES STICKER SHEET        12
# ...                                 ...       ...
# 541894         CIRCUS PARADE LUNCH BOX         12
# 541895   PLASTERS IN TIN CIRCUS PARADE         12
# 541896        PLASTERS IN TIN STRONGMAN        12
# 541902              SPACEBOY LUNCH BOX         12
# 541904      PACK OF 20 SPACEBOY NAPKINS        12
#
# [132631 rows x 2 columns]

# %%
next_1000col = df.iloc[1000:2001,3:6]
next_1000col.to_json('OnlineRetail.json')
next_1000col
# Out:
#       Quantity      InvoiceDate  UnitPrice
# 1000         1  12/1/2010 12:43       1.25
# 1001         1  12/1/2010 12:43       1.25
# 1002         1  12/1/2010 12:43       1.25
# 1003         1  12/1/2010 12:43       1.25
# 1004        12  12/1/2010 12:43       0.29
# ...        ...              ...        ...
# 1996         1  12/1/2010 14:34       2.95
# 1997         3  12/1/2010 14:34       1.65
# 1998         1  12/1/2010 14:34       4.95
# 1999         1  12/1/2010 14:34       2.95
# 2000         2  12/1/2010 14:34       1.25
#
# [1001 rows x 3 columns]

# %%
result = df.loc[df['InvoiceNo'] == "536365"]
result.to_html('OnlineRetail.html')

result
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom
# ...
